# %%
from os.path import dirname, abspath, join
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dirPath = abspath(dirname(''))
data_file = 'corn_sfty_100.bag.csv'
data_file = join(join(dirname(dirPath),'data'), data_file)

with open(data_file, 'r') as f:
    data_raw = pd.read_csv(f)

with open(join(join(dirname(dirPath),'data'), 'path.pkl'), 'rb') as f:
    path = pickle.load(f)
data_raw
# Out:
#                  t  speed     x_pos     y_pos  deviation  track_progress
# 0         0.000140  0.000 -0.173513  1.057628   0.065681             NaN
# 1         0.000340  0.000 -0.173513  1.057628   0.065681             NaN
# 2         0.000488  0.000 -0.173513  1.057628   0.065681             NaN
# 3         0.000788  1.615 -0.173513  1.057628   0.065681             NaN
# 4         0.000872  1.615 -0.173513  1.057628   0.065681             NaN
# ...            ...    ...       ...       ...        ...             ...
# 1249631  82.039870  0.000 -3.136133 -0.250765   2.614019             NaN
# 1249632  82.039957  0.000 -3.136133 -0.250765   2.614019             NaN
# 1249633  82.040038  0.000 -3.136133 -0.250765   2.614019             NaN
# 1249634  82.040092  0.000 -3.136133 -0.250765   2.614019             NaN
# 1249635  82.664325  0.000 -3.136133 -0.250765   2.614019             NaN
#
# [1249636 rows x 6 columns]

# %%
t = data_raw['t']
speed = data_raw['speed']
x_pos = data_raw['x_pos']
y_pos = data_raw['y_pos']
deviation = data_raw['deviation']

grad = 1
start = 0
end = 500000

fig = plt.figure(figsize=(20,10))
plt.plot(t[start:end][::grad], speed[start:end][::grad], '.')
plt.xlabel('time')
plt.ylabel('speed')
plt.title('speed', fontsize=30)
# Out:
# Text(0.5, 1.0, 'speed')

# %%
path_x = [point['x'] for point in path]
path_y = [point['y'] for point in path]

fig = plt.figure(figsize=(20,10))
plt.plot(x_pos, y_pos, 'b.')
plt.plot(path_x, path_y, 'r.')
plt.legend(['actual path', 'wanted path'], loc='lower right', fontsize=20)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.plot(t, s)

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.axes(projection="3d")

z_line = np.linspace(0, 15, 1000)
x_line = np.cos(z_line)
y_line = np.sin(z_line)
ax.plot3D(path_x, path_y, np.zeros_like(path_x))

z_points = 15 * np.random.random(100)
x_points = np.cos(z_points) + 0.1 * np.random.randn(100)
y_points = np.sin(z_points) + 0.1 * np.random.randn(100)
ax.scatter3D(x_points, y_points, z_points, c=z_points, cmap='hsv');

plt.show()

# %%
def moving_avg(poses):
    N = int(len(poses)/1000)
    n = N
    moving_avg = []
    tmp = []
    for i in range(len(poses)):
        tmp.append(poses[i])
        if(i >= N):
            moving_avg.append(np.mean(tmp))
            tmp = []
            N = n+N
    return moving_avg
    

x_avg = moving_avg(x_pos)
y_avg = moving_avg(y_pos)

# %%
path_avg = [{'x':x, 'y':y} for (x,y) in zip(x_avg, y_avg)]

# %%
def find_closest_points(pose, path, n_points):
    x = pose['x']
    y = pose['y']
    ref_path = path[:]
    distances = [(path_point['x']-x)**2 + (path_point['y']-y)**2 for path_point in ref_path]
    min_elems = []
    for i in range(n_points):
        min_ind = np.argmin(distances)
        min_elems.append(ref_path[min_el])
        del distances[min_ind]
        del ref_path[min_ind]
el = 400
fig = plt.figure(figsize=(20,10))
plt.plot(x_avg, y_avg, '.b')
plt.plot(path_x, path_y, 'g.')
point = {'x':x_avg[el], 'y':y_avg[el]}
plt.scatter(point['x'], point['y'], marker='o', s=400, c='r')
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-739d456e9fbf> in <module>
#      16 point = {'x':x_avg[el], 'y':y_avg[el]}
#      17 plt.scatter(point['x'], point['y'], marker='o', s=400, c='r')
# ---> 18 plt.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
fig = plt.figure(figsize=(20,10))
plt.plot(x_avg, y_avg, '.b')
plt.plot(path_x, path_y, 'r.')

# %%
def rem(l):
    r = l[:]
    del r[2]
l = [1,2,4,7,9,10,20]
rem(l)
l
# Out:
# [1, 2, 4, 7, 9, 10, 20]
